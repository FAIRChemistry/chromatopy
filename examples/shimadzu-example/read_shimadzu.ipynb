# %% [markdown]
# # Shimadzu LC

# %%
# %reload_ext autoreload
# %autoreload 2
from chromatopy.core import ChromHandler
from chromatopy.readers import ShimadzuReader

# %% [markdown]
# ## Load the data from a folder
#
# The folder contains multiple `TXT` files, each file contains the data of a single LC run. The data is mapped to a `ChromatigraphicExperiment` which contains multiple `Experiment` objects, each representing a single run. Each `Experiment` object contains a `Chromatogram` object which contains the actual data. This includes the unprocessed signal over retention time, as well as automatically detected peaks by LCsolution software.

# %%
path_dir = "data"

handler = ChromHandler.read(path_dir, ShimadzuReader)

# %%
ana = handler.add_analyte("caffeine", 8.063)

# %%
handler.visualize_chromatograms()

# %%
handler.injection_times
# Out:
# [0.0, 13.0, 198.0, 214.0, 230.0, 241.0, 253.0, 264.0, 276.0]

# %%
print(handler)
# Out:
# ChromHandler
# ├── id = d2b2334a-a096-48cc-a2a5-5b9992130401
# ├── analytes
# │   └── 0
# │       └── Analyte
# │           ├── id = 4be35037-bd64-4de2-bb42-8b2acf653c8e
# │           ├── name = caffeine
# │           ├── retention_time = 8.063
# │           ├── peaks
# │           │   ├── 0
# │           │   │   └── Peak
# │           │   │       ├── id = 99b38f77-d8cc-46fe-896d-47cd1634215b
# │           │   │       ├── retention_time = 8.063
# │           │   │       ├── retention_time_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 08b15823-9a18-4809-9539-6be1b75e2496
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── peak_start = 7.442
# │           │   │       ├── peak_end = 8.95
# │           │   │       ├── width = 1.5079999999999991
# │           │   │       ├── width_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 4fc1fc11-aeae-4c97-9a1f-046140956b7e
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── area = 2838883.0
# │           │   │       ├── height = 74297.0
# │           │   │       ├── tailing_factor = 0.0
# │           │   │       └── separation_factor = 1.138
# │           │   ├── 1
# │           │   │   └── Peak
# │           │   │       ├── id = f4195d8d-9070-42a8-bd5f-b9954afbb783
# │           │   │       ├── retention_time = 8.063
# │           │   │       ├── retention_time_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = c6e7ebec-3cd9-48ce-b616-916256278d06
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── peak_start = 7.442
# │           │   │       ├── peak_end = 8.95
# │           │   │       ├── width = 1.5079999999999991
# │           │   │       ├── width_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 7e57bf24-68bd-4731-b072-2623cb0e4b17
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── area = 2838883.0
# │           │   │       ├── height = 74297.0
# │           │   │       ├── tailing_factor = 0.0
# │           │   │       └── separation_factor = 1.138
# │           │   ├── 2
# │           │   │   └── Peak
# │           │   │       ├── id = 78f00f82-f34a-441b-aa1d-55c23d6873f4
# │           │   │       ├── retention_time = 8.063
# │           │   │       ├── retention_time_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 0b1bb9b2-3989-4972-a4d2-5b3da66e427d
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── peak_start = 7.442
# │           │   │       ├── peak_end = 8.95
# │           │   │       ├── width = 1.5079999999999991
# │           │   │       ├── width_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = b27e4114-e722-4797-85b8-d29380ec1d5c
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── area = 2838883.0
# │           │   │       ├── height = 74297.0
# │           │   │       ├── tailing_factor = 0.0
# │           │   │       └── separation_factor = 1.138
# │           │   ├── 3
# │           │   │   └── Peak
# │           │   │       ├── id = 9d8656a0-6008-46bd-9b8b-105dde24624c
# │           │   │       ├── retention_time = 8.063
# │           │   │       ├── retention_time_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = a2553258-5bee-4389-b8c5-ffe0593cb336
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── peak_start = 7.442
# │           │   │       ├── peak_end = 8.95
# │           │   │       ├── width = 1.5079999999999991
# │           │   │       ├── width_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 2556f00d-729d-4e29-8296-b2a4169d3325
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── area = 2838883.0
# │           │   │       ├── height = 74297.0
# │           │   │       ├── tailing_factor = 0.0
# │           │   │       └── separation_factor = 1.138
# │           │   ├── 4
# │           │   │   └── Peak
# │           │   │       ├── id = 3f24bc68-85dd-4cfd-8471-7cdad7daf564
# │           │   │       ├── retention_time = 8.063
# │           │   │       ├── retention_time_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 338ed155-a81b-497f-b38f-9578745767c0
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── peak_start = 7.442
# │           │   │       ├── peak_end = 8.95
# │           │   │       ├── width = 1.5079999999999991
# │           │   │       ├── width_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 8a455677-0f31-40c7-b3cb-c57e04b11ce1
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── area = 2838883.0
# │           │   │       ├── height = 74297.0
# │           │   │       ├── tailing_factor = 0.0
# │           │   │       └── separation_factor = 1.138
# │           │   ├── 5
# │           │   │   └── Peak
# │           │   │       ├── id = a925b5aa-4080-4ad9-a22e-59986018f19a
# │           │   │       ├── retention_time = 8.063
# │           │   │       ├── retention_time_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 4972b9c7-f131-446c-a159-d16e411b27e0
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── peak_start = 7.442
# │           │   │       ├── peak_end = 8.95
# │           │   │       ├── width = 1.5079999999999991
# │           │   │       ├── width_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 9da5b22c-f639-4969-9fc0-f57c5e30d908
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── area = 2838883.0
# │           │   │       ├── height = 74297.0
# │           │   │       ├── tailing_factor = 0.0
# │           │   │       └── separation_factor = 1.138
# │           │   ├── 6
# │           │   │   └── Peak
# │           │   │       ├── id = 925270d2-fcb7-4fd5-b7be-77999301fbcd
# │           │   │       ├── retention_time = 8.084
# │           │   │       ├── retention_time_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 546e890f-8d02-430f-9875-d000f2c5e80b
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── peak_start = 7.642
# │           │   │       ├── peak_end = 9.083
# │           │   │       ├── width = 1.4409999999999998
# │           │   │       ├── width_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 2d796982-c46f-470d-8422-b559f95ded92
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── area = 1536580.0
# │           │   │       ├── height = 38274.0
# │           │   │       ├── tailing_factor = 0.0
# │           │   │       └── separation_factor = 1.136
# │           │   ├── 7
# │           │   │   └── Peak
# │           │   │       ├── id = f6af37bd-5741-4417-aace-cca1981557fc
# │           │   │       ├── retention_time = 8.07
# │           │   │       ├── retention_time_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 0ad03327-47b3-48d8-a210-ed634e5f8955
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── peak_start = 7.642
# │           │   │       ├── peak_end = 9.033
# │           │   │       ├── width = 1.3909999999999991
# │           │   │       ├── width_unit
# │           │   │       │   └── Unit
# │           │   │       │       ├── id = 543ecde1-0190-44db-ab16-fd9ea458ee62
# │           │   │       │       ├── name = min
# │           │   │       │       └── bases
# │           │   │       │           └── 0
# │           │   │       │               └── BaseUnit
# │           │   │       │                   ├── scale = 60.0
# │           │   │       │                   ├── kind = s
# │           │   │       │                   └── exponent = 1.0
# │           │   │       ├── area = 1360749.0
# │           │   │       ├── height = 33114.0
# │           │   │       ├── tailing_factor = 0.0
# │           │   │       └── separation_factor = 1.132
# │           │   └── 8
# │           │       └── Peak
# │           │           ├── id = 4ad1e916-665a-4a78-8840-7d9f22519bc8
# │           │           ├── retention_time = 7.985
# │           │           ├── retention_time_unit
# │           │           │   └── Unit
# │           │           │       ├── id = a2550191-9f7a-44bd-a7c1-ec99a4c7ed9c
# │           │           │       ├── name = min
# │           │           │       └── bases
# │           │           │           └── 0
# │           │           │               └── BaseUnit
# │           │           │                   ├── scale = 60.0
# │           │           │                   ├── kind = s
# │           │           │                   └── exponent = 1.0
# │           │           ├── peak_start = 7.558
# │           │           ├── peak_end = 8.967
# │           │           ├── width = 1.4090000000000007
# │           │           ├── width_unit
# │           │           │   └── Unit
# │           │           │       ├── id = d35953dd-5f87-4d3d-9d1e-b7aec0e0f028
# │           │           │       ├── name = min
# │           │           │       └── bases
# │           │           │           └── 0
# │           │           │               └── BaseUnit
# │           │           │                   ├── scale = 60.0
# │           │           │                   ├── kind = s
# │           │           │                   └── exponent = 1.0
# │           │           ├── area = 1442312.0
# │           │           ├── height = 35393.0
# │           │           ├── tailing_factor = 0.0
# │           │           └── separation_factor = 1.125
# │           ├── injection_times = [2023-12-12 11:15:12, 2023-12-12 11:15:25, 2023-12-12 11:18:30, 2023-12-12 11:18:46, 2023-12-12 11:19:02, ...]
# │           ├── standard
# │           │   └── Standard
# │           │       └── id = f8b093ee-5525-4c8d-9788-ae7ce97671ef
# │           └── role = analyte
# └── measurements
#     ├── 0
#     │   └── Measurement
#     │       ├── id = 1859fb3c-a059-486b-8260-d6ba0b4fa0ab
#     │       ├── chromatograms
#     │       │   └── 0
#     │       │       └── Chromatogram
#     │       │           ├── id = 1f7978cb-0585-45db-bf4e-e2d6a2cea27f
#     │       │           ├── peaks
#     │       │           │   ├── 0
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = c9664184-bbbd-47e4-9309-ed47b214094b
#     │       │           │   │       ├── retention_time = 0.143
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = d07abb89-fb3f-4002-b278-bd0c964089cf
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 0.017
#     │       │           │   │       ├── peak_end = 0.342
#     │       │           │   │       ├── width = 0.325
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 74471a01-0fbc-436b-9b5e-d744ff530508
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 1278.0
#     │       │           │   │       ├── height = 107.0
#     │       │           │   │       ├── tailing_factor = 1.16
#     │       │           │   │       └── separation_factor = 0.0
#     │       │           │   ├── 1
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 338b7ac2-e33f-4fd9-8e6e-070d1dfb9ff7
#     │       │           │   │       ├── retention_time = 2.677
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 3dbe1a60-f405-48eb-9d78-a6891a551170
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 2.6
#     │       │           │   │       ├── peak_end = 2.842
#     │       │           │   │       ├── width = 0.242
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 0f116e43-5fae-4b97-bf52-9b6a84511d35
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 7633.0
#     │       │           │   │       ├── height = 868.0
#     │       │           │   │       ├── tailing_factor = 1.54
#     │       │           │   │       └── separation_factor = 0.0
#     │       │           │   ├── 2
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 2bed9b98-de90-4e7f-973c-d634f59118e7
#     │       │           │   │       ├── retention_time = 3.113
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = b03d6204-438f-4c69-b794-f349066ccd5b
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 2.867
#     │       │           │   │       ├── peak_end = 3.492
#     │       │           │   │       ├── width = 0.625
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = d640d025-7c9e-4582-bd98-b5c4fa65bcfe
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 74069.0
#     │       │           │   │       ├── height = 3235.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.172
#     │       │           │   ├── 3
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = a90da93a-a6e6-42da-9265-e208bab77f8a
#     │       │           │   │       ├── retention_time = 3.674
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 0328e9e2-ded8-46e8-9389-330ab9e2849a
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 3.492
#     │       │           │   │       ├── peak_end = 4.225
#     │       │           │   │       ├── width = 0.7329999999999997
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = a49d4457-0692-46bd-95cf-f8cc80086c3d
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 62448.0
#     │       │           │   │       ├── height = 1896.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.189
#     │       │           │   ├── 4
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = dfdc6b8e-c1f1-48ea-a4ba-731fb83e3c7c
#     │       │           │   │       ├── retention_time = 4.541
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 93242d30-4dbf-47fc-b9df-e5cde3f0ac61
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 4.225
#     │       │           │   │       ├── peak_end = 4.858
#     │       │           │   │       ├── width = 0.633
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = e01fe765-c19e-45e5-b2bb-7882299af094
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 61821.0
#     │       │           │   │       ├── height = 2075.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.246
#     │       │           │   ├── 5
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = a7d07f66-8d9d-4ac5-9220-bb86fc3399c1
#     │       │           │   │       ├── retention_time = 5.264
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = ece4c95a-40f7-44d9-a713-626ddb2046b0
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 4.858
#     │       │           │   │       ├── peak_end = 6.025
#     │       │           │   │       ├── width = 1.1670000000000007
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 74f1c62d-7df8-4722-bbc1-9731fb1e1f85
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 591150.0
#     │       │           │   │       ├── height = 23289.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.164
#     │       │           │   ├── 6
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = e3759283-5753-48ab-b9d4-9441d5255896
#     │       │           │   │       ├── retention_time = 6.234
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 0d1d43ad-6172-4636-a35b-20b93068e2e2
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 6.025
#     │       │           │   │       ├── peak_end = 6.417
#     │       │           │   │       ├── width = 0.39199999999999946
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = f414548f-e49d-491b-8f0d-30023ddc2b67
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 69898.0
#     │       │           │   │       ├── height = 3040.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.189
#     │       │           │   ├── 7
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 87b35a83-0617-4f1d-982e-83a057851f13
#     │       │           │   │       ├── retention_time = 6.57
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = f287f514-1306-4a79-803e-7f7694537404
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 6.417
#     │       │           │   │       ├── peak_end = 6.708
#     │       │           │   │       ├── width = 0.29100000000000037
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 75c54a1e-e2a8-4e68-bc17-36917ab22668
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 51229.0
#     │       │           │   │       ├── height = 2962.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.055
#     │       │           │   ├── 8
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 94814aa9-1cd9-4108-b770-0bc3e7612643
#     │       │           │   │       ├── retention_time = 7.099
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = fc1885d5-4ac1-4442-852c-10bbf0fbdf6a
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 6.708
#     │       │           │   │       ├── peak_end = 7.442
#     │       │           │   │       ├── width = 0.734
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 2cc34db9-62ba-4ec0-9aa0-232c6e2144f0
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 271461.0
#     │       │           │   │       ├── height = 9085.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.082
#     │       │           │   ├── 9
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 99b38f77-d8cc-46fe-896d-47cd1634215b
#     │       │           │   │       ├── retention_time = 8.063
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 08b15823-9a18-4809-9539-6be1b75e2496
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 7.442
#     │       │           │   │       ├── peak_end = 8.95
#     │       │           │   │       ├── width = 1.5079999999999991
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 4fc1fc11-aeae-4c97-9a1f-046140956b7e
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 2838883.0
#     │       │           │   │       ├── height = 74297.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.138
#     │       │           │   ├── 10
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 6cc10ffa-eea5-4dbc-86ee-7c26a377fcfa
#     │       │           │   │       ├── retention_time = 9.083
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 0df4b682-d93e-47d7-9bd6-b07120b7a6ab
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 8.95
#     │       │           │   │       ├── peak_end = 10.367
#     │       │           │   │       ├── width = 1.4170000000000016
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 24baeada-a86d-42f5-9d8c-a7d819a2e2c5
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 458569.0
#     │       │           │   │       ├── height = 7811.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.129
#     │       │           │   ├── 11
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 9dbd47f2-5ac4-4461-af4e-4fb3dc9f1bbc
#     │       │           │   │       ├── retention_time = 10.392
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = b78cf477-4efe-4ec7-bd42-250908f59487
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 10.367
#     │       │           │   │       ├── peak_end = 11.067
#     │       │           │   │       ├── width = 0.6999999999999993
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 88dd38f4-0b71-4995-8608-cf7dcdb35150
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 150804.0
#     │       │           │   │       ├── height = 3848.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.146
#     │       │           │   ├── 12
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 80b76f35-d2fa-475a-8faa-686fd9bd76cf
#     │       │           │   │       ├── retention_time = 11.391
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 54bed51e-eaeb-470e-a2f0-f18456983b9d
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 11.067
#     │       │           │   │       ├── peak_end = 12.442
#     │       │           │   │       ├── width = 1.375
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 2a88d494-dd26-4cd9-bc69-2689c67b48ba
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 273652.0
#     │       │           │   │       ├── height = 3881.0
#     │       │           │   │       ├── tailing_factor = 0.0
#     │       │           │   │       └── separation_factor = 1.098
#     │       │           │   └── 13
#     │       │           │       └── Peak
#     │       │           │           ├── id = 1fc61782-d7de-468c-bbc2-7f1f93a61cfc
#     │       │           │           ├── retention_time = 12.567
#     │       │           │           ├── retention_time_unit
#     │       │           │           │   └── Unit
#     │       │           │           │       ├── id = 39ac46d4-5f5d-49ab-bcaf-a1a49d259608
#     │       │           │           │       ├── name = min
#     │       │           │           │       └── bases
#     │       │           │           │           └── 0
#     │       │           │           │               └── BaseUnit
#     │       │           │           │                   ├── scale = 60.0
#     │       │           │           │                   ├── kind = s
#     │       │           │           │                   └── exponent = 1.0
#     │       │           │           ├── peak_start = 12.442
#     │       │           │           ├── peak_end = 14.967
#     │       │           │           ├── width = 2.5250000000000004
#     │       │           │           ├── width_unit
#     │       │           │           │   └── Unit
#     │       │           │           │       ├── id = 163f4f7b-b9b4-4dc6-a92a-0dddb2171ddd
#     │       │           │           │       ├── name = min
#     │       │           │           │       └── bases
#     │       │           │           │           └── 0
#     │       │           │           │               └── BaseUnit
#     │       │           │           │                   ├── scale = 60.0
#     │       │           │           │                   ├── kind = s
#     │       │           │           │                   └── exponent = 1.0
#     │       │           │           ├── area = 184099.0
#     │       │           │           ├── height = 2616.0
#     │       │           │           ├── tailing_factor = 0.0
#     │       │           │           └── separation_factor = 1.105
#     │       │           ├── retention_times = [0.0, 0.00833, 0.01667, 0.025, 0.03333, ...]
#     │       │           ├── time_unit
#     │       │           │   └── Unit
#     │       │           │       ├── id = 497d976a-fe88-451b-9f64-22ddee9d79e2
#     │       │           │       ├── name = min
#     │       │           │       └── bases
#     │       │           │           └── 0
#     │       │           │               └── BaseUnit
#     │       │           │                   ├── scale = 60.0
#     │       │           │                   ├── kind = s
#     │       │           │                   └── exponent = 1.0
#     │       │           ├── signals = [-0.132, -0.132, -0.052000000000000005, 0.003, 0.008, ...]
#     │       │           ├── wavelength = 215.0
#     │       │           └── type = uv/visible absorbance detector
#     │       ├── timestamp = 2023-12-12 11:15:12
#     │       ├── injection_volume = 20.0
#     │       └── injection_volume_unit
#     │           └── Unit
#     │               ├── id = 4c5af662-b75c-4a4a-833b-3f872b48875c
#     │               ├── name = ul
#     │               └── bases
#     │                   └── 0
#     │                       └── BaseUnit
#     │                           ├── scale = 1e-06
#     │                           ├── kind = l
#     │                           └── exponent = 1.0
#     ├── 1
#     │   └── Measurement
#     │       ├── id = 25895eb4-90ac-4d2a-a8ba-c1b9fe29a549
#     │       ├── chromatograms
#     │       │   └── 0
#     │       │       └── Chromatogram
#     │       │           ├── id = e79993ae-d185-45c7-a51a-b03d78f6289d
#     │       │           ├── peaks
#     │       │           │   ├── 0
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 5f2eed96-b499-4afe-9ddc-25afd2914ad9
#     │       │           │   │       ├── retention_time = 0.143
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 523f87a4-3a7a-4595-872b-6f869e6524b8
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 0.017
#     │       │           │   │       ├── peak_end = 0.342
#     │       │           │   │       ├── width = 0.325
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 945b5083-5714-476e-a8ba-4ec38cb9f1ec
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 1278.0
#     │       │           │   │       ├── height = 107.0
#     │       │           │   │       ├── tailing_factor = 1.16
#     │       │           │   │       └── separation_factor = 0.0
#     │       │           │   ├── 1
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 9d15d6f8-9bff-4756-9611-ebdc6a36cef7
#     │       │           │   │       ├── retention_time = 2.677
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 458e0be3-88a5-4dae-b759-fe507221669e
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── peak_start = 2.6
#     │       │           │   │       ├── peak_end = 2.842
#     │       │           │   │       ├── width = 0.242
#     │       │           │   │       ├── width_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 24148aa8-9d18-4818-ae90-d01d40b79e57
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
#     │       │           │   │       │                   ├── kind = s
#     │       │           │   │       │                   └── exponent = 1.0
#     │       │           │   │       ├── area = 7633.0
#     │       │           │   │       ├── height = 868.0
#     │       │           │   │       ├── tailing_factor = 1.54
#     │       │           │   │       └── separation_factor = 0.0
#     │       │           │   ├── 2
#     │       │           │   │   └── Peak
#     │       │           │   │       ├── id = 6e8e195f-7719-485d-b02f-de709e97918c
#     │       │           │   │       ├── retention_time = 3.113
#     │       │           │   │       ├── retention_time_unit
#     │       │           │   │       │   └── Unit
#     │       │           │   │       │       ├── id = 7b0f3d1f-6dd8-4792-8fea-63f594922d56
#     │       │           │   │       │       ├── name = min
#     │       │           │   │       │       └── bases
#     │       │           │   │       │           └── 0
#     │       │           │   │       │               └── BaseUnit
#     │       │           │   │       │                   ├── scale = 60.0
# ...
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── peak_start = 6.742
#             │           │   │       ├── peak_end = 7.558
#             │           │   │       ├── width = 0.8159999999999998
#             │           │   │       ├── width_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = 52a17a83-98f8-4401-91f6-fab0a2294669
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── area = 1029154.0
#             │           │   │       ├── height = 40661.0
#             │           │   │       ├── tailing_factor = 0.0
#             │           │   │       └── separation_factor = 1.372
#             │           │   ├── 6
#             │           │   │   └── Peak
#             │           │   │       ├── id = 4ad1e916-665a-4a78-8840-7d9f22519bc8
#             │           │   │       ├── retention_time = 7.985
#             │           │   │       ├── retention_time_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = a2550191-9f7a-44bd-a7c1-ec99a4c7ed9c
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── peak_start = 7.558
#             │           │   │       ├── peak_end = 8.967
#             │           │   │       ├── width = 1.4090000000000007
#             │           │   │       ├── width_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = d35953dd-5f87-4d3d-9d1e-b7aec0e0f028
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── area = 1442312.0
#             │           │   │       ├── height = 35393.0
#             │           │   │       ├── tailing_factor = 0.0
#             │           │   │       └── separation_factor = 1.125
#             │           │   ├── 7
#             │           │   │   └── Peak
#             │           │   │       ├── id = 20cfe747-e169-4c75-80b3-27bfe0b518da
#             │           │   │       ├── retention_time = 9.339
#             │           │   │       ├── retention_time_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = c5cca78d-e8f2-471f-a64d-9307d2510ce2
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── peak_start = 8.967
#             │           │   │       ├── peak_end = 10.508
#             │           │   │       ├── width = 1.5409999999999986
#             │           │   │       ├── width_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = 880d192e-4c7d-4e78-a7f8-a79c09172a04
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── area = 452709.0
#             │           │   │       ├── height = 11137.0
#             │           │   │       ├── tailing_factor = 0.0
#             │           │   │       └── separation_factor = 1.174
#             │           │   ├── 8
#             │           │   │   └── Peak
#             │           │   │       ├── id = f31ce9d7-cce4-4eab-9587-837d948343bd
#             │           │   │       ├── retention_time = 10.759
#             │           │   │       ├── retention_time_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = 7357f6c8-8d3d-422f-9f7b-0b7a751d0c8f
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── peak_start = 10.508
#             │           │   │       ├── peak_end = 11.208
#             │           │   │       ├── width = 0.7000000000000011
#             │           │   │       ├── width_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = a996297e-2936-4d04-8292-6cfbe1ac78a9
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── area = 69599.0
#             │           │   │       ├── height = 1970.0
#             │           │   │       ├── tailing_factor = 0.0
#             │           │   │       └── separation_factor = 1.155
#             │           │   ├── 9
#             │           │   │   └── Peak
#             │           │   │       ├── id = add0b39b-68c5-489d-b042-d3a9bf9621c6
#             │           │   │       ├── retention_time = 11.745
#             │           │   │       ├── retention_time_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = 96e4296a-e28d-4d61-967e-5a156b5cb768
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── peak_start = 11.208
#             │           │   │       ├── peak_end = 12.542
#             │           │   │       ├── width = 1.3339999999999996
#             │           │   │       ├── width_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = ffafb20b-b573-45e2-b7c5-2fe3cdb9b3a1
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── area = 230639.0
#             │           │   │       ├── height = 4848.0
#             │           │   │       ├── tailing_factor = 0.0
#             │           │   │       └── separation_factor = 1.093
#             │           │   ├── 10
#             │           │   │   └── Peak
#             │           │   │       ├── id = aaa10926-611a-4393-ba8a-3059fe49ee6c
#             │           │   │       ├── retention_time = 12.649
#             │           │   │       ├── retention_time_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = a1ff5dd4-f84b-4862-b7ea-cedc00572d2e
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── peak_start = 12.542
#             │           │   │       ├── peak_end = 13.008
#             │           │   │       ├── width = 0.4659999999999993
#             │           │   │       ├── width_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = 9bfb34bf-8f3e-44a1-b686-e49ea19e4ca2
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── area = 42545.0
#             │           │   │       ├── height = 1598.0
#             │           │   │       ├── tailing_factor = 0.0
#             │           │   │       └── separation_factor = 1.078
#             │           │   ├── 11
#             │           │   │   └── Peak
#             │           │   │       ├── id = 8a0a4baa-ef37-4315-a955-7f7c79d2bec0
#             │           │   │       ├── retention_time = 13.067
#             │           │   │       ├── retention_time_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = 18204f6e-7ce3-465c-ad34-d554177952cd
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── peak_start = 13.008
#             │           │   │       ├── peak_end = 14.175
#             │           │   │       ├── width = 1.1670000000000016
#             │           │   │       ├── width_unit
#             │           │   │       │   └── Unit
#             │           │   │       │       ├── id = 44909843-a7ad-4adc-9d5d-02eae4088639
#             │           │   │       │       ├── name = min
#             │           │   │       │       └── bases
#             │           │   │       │           └── 0
#             │           │   │       │               └── BaseUnit
#             │           │   │       │                   ├── scale = 60.0
#             │           │   │       │                   ├── kind = s
#             │           │   │       │                   └── exponent = 1.0
#             │           │   │       ├── area = 51787.0
#             │           │   │       ├── height = 1396.0
#             │           │   │       ├── tailing_factor = 0.0
#             │           │   │       └── separation_factor = 1.034
#             │           │   └── 12
#             │           │       └── Peak
#             │           │           ├── id = 2ab3b005-fdd2-45b0-b802-640093a08040
#             │           │           ├── retention_time = 14.275
#             │           │           ├── retention_time_unit
#             │           │           │   └── Unit
#             │           │           │       ├── id = c85de058-fb3b-4e41-9f97-c2320c2e9801
#             │           │           │       ├── name = min
#             │           │           │       └── bases
#             │           │           │           └── 0
#             │           │           │               └── BaseUnit
#             │           │           │                   ├── scale = 60.0
#             │           │           │                   ├── kind = s
#             │           │           │                   └── exponent = 1.0
#             │           │           ├── peak_start = 14.175
#             │           │           ├── peak_end = 14.4
#             │           │           ├── width = 0.22499999999999964
#             │           │           ├── width_unit
#             │           │           │   └── Unit
#             │           │           │       ├── id = b7462be4-ecdd-4b69-8543-f90e46e9b7f1
#             │           │           │       ├── name = min
#             │           │           │       └── bases
#             │           │           │           └── 0
#             │           │           │               └── BaseUnit
#             │           │           │                   ├── scale = 60.0
#             │           │           │                   ├── kind = s
#             │           │           │                   └── exponent = 1.0
#             │           │           ├── area = 1013.0
#             │           │           ├── height = 86.0
#             │           │           ├── tailing_factor = 0.0
#             │           │           └── separation_factor = 1.094
#             │           ├── retention_times = [0.0, 0.00833, 0.01667, 0.025, 0.03333, ...]
#             │           ├── time_unit
#             │           │   └── Unit
#             │           │       ├── id = 2dac2f6c-2669-4339-96ca-ed678858ccfe
#             │           │       ├── name = min
#             │           │       └── bases
#             │           │           └── 0
#             │           │               └── BaseUnit
#             │           │                   ├── scale = 60.0
#             │           │                   ├── kind = s
#             │           │                   └── exponent = 1.0
#             │           ├── signals = [0.001, 0.001, 0.006, 0.004, 0.011, ...]
#             │           ├── wavelength = 215.0
#             │           └── type = uv/visible absorbance detector
#             ├── timestamp = 2023-12-12 11:19:48
#             ├── injection_volume = 20.0
#             └── injection_volume_unit
#                 └── Unit
#                     ├── id = 9252a2db-35c5-442b-a6fe-aebce9930320
#                     ├── name = ul
#                     └── bases
#                         └── 0
#                             └── BaseUnit
#                                 ├── scale = 1e-06
#                                 ├── kind = l
#                                 └── exponent = 1.0
