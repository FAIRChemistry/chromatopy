# %% [markdown]
# # Shimadzu LC

# %%
# %reload_ext autoreload
# %autoreload 2
from chromatopy.core import ChromHandler
from chromatopy.readers import ShimadzuReader

# %% [markdown]
# ## Load the data from a folder
#
# The folder contains multiple `TXT` files, each file contains the data of a single LC run. The data is mapped to a `ChromatigraphicExperiment` which contains multiple `Experiment` objects, each representing a single run. Each `Experiment` object contains a `Chromatogram` object which contains the actual data. This includes the unprocessed signal over retention time, as well as automatically detected peaks by LCsolution software.

# %%
path_dir = "data"

handler = ChromHandler.read(path_dir, ShimadzuReader)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 path_dir = "data"
# ----> 3 handler = ChromHandler.read(path_dir, ShimadzuReader)
#
# File ~/Documents/GitHub/chromatopy/chromatopy/core/chromhandler.py:329, in ChromHandler.read(cls, path, reader)
#     310 @classmethod
#     311 def read(cls, path: str, reader: AbstractReader):
#     312     """
#     313     Reads data from a file or directory using the specified reader.
#     314
#    (...)
#     326
#     327     """
# --> 329     measurements = reader(path).read()
#     330     instance = cls(measurements=measurements)
#     332     # sort measurements by timestamp
#
# File ~/Documents/GitHub/chromatopy/chromatopy/readers/shimadzu.py:28, in ShimadzuReader.read(self)
#      27 def read(self):
# ---> 28     return [self.read_file(f) for f in self._paths()]
#
# File ~/Documents/GitHub/chromatopy/chromatopy/readers/shimadzu.py:47, in ShimadzuReader.read_file(self, path)
#      44 timestamp = measurement_dict["timestamp"]
#      46 peak_dict = self.extract_peaks(sections)
# ---> 47 print(peak_dict["retention_time"])
#      48 peak_dict["timestamp"] = timestamp + peak_dict["retention_time"]
#      49 chromatogram_dict = self.extract_signal(sections)
#
# TypeError: list indices must be integers or slices, not str

# %%
caffeine = handler.add_analyte("caffeine", 8.063)

# %%
handler.visualize_chromatograms()

# %%
# Out:
# 2838883.0
