# %%
# %reload_ext autoreload
# %autoreload 2
from chromatopy.core import Chromatogram

# %%
path = "/Users/max/Documents/training_course/katrin/2023-12-08 01-20-41+01-00-01.dx_DAD1A.CSV"
c = Chromatogram.from_csv(path, time_unit="min")

# %%
fitter = c.fit()
# Out:
# Performing baseline correction: 100%|██████████| 374/374 [00:00<00:00, 458.27it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:06<00:00,  6.61s/it]

# %%
c.plot()
